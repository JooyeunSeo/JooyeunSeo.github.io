# %% [markdown]
# # Import
# `Ctrl + Enter` : 현재 셀 실행<br>
# `Shift + Enter` : 현재 셀 실행 후 다음 셀로 이동<br>
# `Alt + Enter` : 현재 셀 실행 후 아래에 새 셀 삽입<br>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Pandas Schema & Code

# %%
data = [['Dog', 'Golden Retriever', 1, 5], ['Dog', 'German Shepherd', 2, 5], ['Dog', 'Mule', 200, 1], ['Cat', 'Shirazi', 5, 2], ['Cat', 'Siamese', 3, 3], ['Cat', 'Sphynx', 7, 4]]
queries = pd.DataFrame(data, columns=['query_name', 'result', 'position', 'rating']).astype({'query_name':'object', 'result':'object', 'position':'Int64', 'rating':'Int64'})

# %%
df = queries.assign(
        ratio=queries['rating'] / queries['position'],
        poor=queries['rating'] < 3
    )
a = df.groupby('query_name', sort=False).agg(
            quality=('ratio', 'mean'),
            poor_query_percentage=('poor', lambda x: x.mean() * 100)
        ).round(2).reset_index()
a
# Out:
#   query_name  quality  poor_query_percentage
# 0        Dog      2.5                   0.33
# 1        Cat     0.66                   0.33
